# %% [markdown]
# <a href="https://colab.research.google.com/github/silaamohammedyousri-web/medical-image-Task3/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install medclip
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 44.3 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=28307861b16151d3e53506a4fe1961b32381d246a063d037524160c1c7b41126
#   Stored in directory: /root/.cache/pip/wheels/01/46/3b/e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
# Successfully built wget
# ...

# %%
# !pip install torch torchvision
# !pip install medclip
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 92.4 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 2.10.0+cu128

# %%
# !pip install medclip faiss-cpu

# %%
pip install torch

# %%
# !pip install torch

# %%
# !pip install medclip faiss-cpu torch torchvision transformers pillow numpy matplotlib

# %%
# !pip install git+https://github.com/RyanWangZf/MedCLIP.git
# !pip install faiss-cpu
# !pip install transformers pillow numpy torch torchvision
# Out:
# ...
#   Cloning https://github.com/RyanWangZf/MedCLIP.git to /tmp/pip-req-build-zopf65qp
#   Running command git clone --filter=blob:none --quiet https://github.com/RyanWangZf/MedCLIP.git /tmp/pip-req-build-zopf65qp
#   Resolved https://github.com/RyanWangZf/MedCLIP.git to commit 9c3396f20d5d54e4fae241b8cb06ca45848e98c9
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.5/90.5 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.9/314.9 kB 22.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 80.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 28.1 MB/s eta 0:00:00
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
# ...

# %%
# !pip install git+https://github.com/RyanWangZf/MedCLIP.git --quiet
# !pip install faiss-cpu --quiet
# !pip install transformers pillow numpy torch torchvision --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for tokenizers
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (tokenizers)

# %%
# !pip install --upgrade pip
# !pip install setuptools wheel
# !pip install tokenizers==0.13.3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 33.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#   Using cached tokenizers-0.13.3.tar.gz (314 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> tokenizers

# %%
# !pip install git+https://github.com/RyanWangZf/MedCLIP.git --no-build-isolation
# Out:
# ...
#   Cloning https://github.com/RyanWangZf/MedCLIP.git to /tmp/pip-req-build-pabu0n91
#   Running command git clone --filter=blob:none --quiet https://github.com/RyanWangZf/MedCLIP.git /tmp/pip-req-build-pabu0n91
#   Resolved https://github.com/RyanWangZf/MedCLIP.git to commit 9c3396f20d5d54e4fae241b8cb06ca45848e98c9
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached transformers-4.24.0-py3-none-any.whl.metadata (90 kB)
# ...
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached tokenizers-0.13.3.tar.gz (314 kB)
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (pyproject.toml) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> tokenizers
#
# ...

# %%
# !pip uninstall -y tokenizers transformers
# !pip uninstall -y medclip
# Out:
# Found existing installation: tokenizers 0.22.2
# Uninstalling tokenizers-0.22.2:
#   Successfully uninstalled tokenizers-0.22.2
# Found existing installation: transformers 5.0.0
# Uninstalling transformers-5.0.0:
#   Successfully uninstalled transformers-5.0.0
# Found existing installation: MedCLIP 0.0.3
# Uninstalling MedCLIP-0.0.3:
#   Successfully uninstalled MedCLIP-0.0.3

# %%
# !pip install transformers==4.28.1
# !pip install tokenizers==0.13.2
# !pip install huggingface-hub==0.13.3
# !pip install faiss-cpu
# !pip install git+https://github.com/RyanWangZf/MedCLIP.git --no-build-isolation
# Out:
# ...
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached tokenizers-0.13.3.tar.gz (314 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 24.9 MB/s  0:00:00
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> tokenizers
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
# ...

# %%
# !pip install git+https://github.com/openai/CLIP.git
# !pip install torch torchvision faiss-cpu pillow numpy matplotlib
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-x3jz03tm
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-x3jz03tm
#   Resolved https://github.com/openai/CLIP.git to commit ded190a052fdf4585bd685cee5bc96e0310d2c93
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369550 sha256=23d1bab7f2c6465b16f8505810eb60cfdb6c650f8bf4b57163bf6395d15cae6b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xa2mgcmr/wheels/35/3e/df/3d24cbfb3b6a06f17a2bfd7d1138900d4365d9028aa8f6e92f
# Successfully built clip
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [clip]
# ...

# %%
import torch
import clip
from PIL import Image
import numpy as np
import faiss
import os

device = "cuda" if torch.cuda.is_available() else "cpu"

model, preprocess = clip.load("ViT-B/32", device=device)
# Out:
# 100%|████████████████████████████████████████| 338M/338M [00:01<00:00, 195MiB/s]

# %%
def get_embedding(image_path):
    image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)

    with torch.no_grad():
        emb = model.encode_image(image)

    return emb.cpu().numpy()

# %%
# !mkdir -p images

# %%
image_folder = "/content"

import os

for img in os.listdir(image_folder):
    print(img)
# Out:
# .config
# images
# sample_data

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-fdacbd0f-bef3-4a3f-83fd-bb8d85763a6e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdacbd0f-bef3-4a3f-83fd-bb8d85763a6e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

print(os.listdir("/content"))
# Out:
# ['.config', '00000019_000.png', '00000080_004.png', 'images', '00000030_000.png', '00000086_002.png', '00000066_000.png', '00000032_035.png', 'sample_data']

# %%
image_folder = "/content"

embeddings = []
paths = []

valid_extensions = [".png", ".jpg", ".jpeg"]

import os

for file in os.listdir(image_folder):

    if any(file.lower().endswith(ext) for ext in valid_extensions):

        path = os.path.join(image_folder, file)

        emb = get_embedding(path)

        embeddings.append(emb)
        paths.append(path)

embeddings = np.vstack(embeddings)

print("Embeddings extracted ✅")
# Out:
# Embeddings extracted ✅

# %%
import faiss

dim = embeddings.shape[1]

index = faiss.IndexFlatL2(dim)
index.add(embeddings)

print("Search index ready ✅")
# Out:
# Search index ready ✅

# %%
def search(query_image, k=3):

    query_emb = get_embedding(query_image)

    D, I = index.search(query_emb, k)

    print("Similar chest images found 👇")

    for i in I[0]:
        print(paths[i])

# %%
search("/content/00000019_000.png", k=3)
# Out:
# Similar chest images found 👇
# /content/00000019_000.png
# /content/00000066_000.png
# /content/00000030_000.png

# %%
import torch
import clip
import faiss
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

# %%
# !git remote remove origin
